# %%
 from scipy import ndimage

# %%
ndimage.imread?

# %%
tmp_array = ndimage.imread('F:/cifar10/data/train/1.png')

# %%
tmp_array.shape
# Out:
# (32, 32, 3)

# %%
from matplotlib import pyplot
from scipy.misc import toimage

# %%
pyplot.imshow(toimage(tmp_array))
pyplot.show()
