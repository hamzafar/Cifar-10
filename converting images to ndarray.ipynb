# %% [markdown]
# # Data Preperation

# %%
from scipy import ndimage
import numpy as np

# %%
import pandas as pd

# %%
# tmp_array = ndimage.imread('F:/cifar10/data/train/2.png')

# tmp_array.shape

# %%
def convert_images_to_array(path, length):
    lst_train = []
#     train_path = 'F:/cifar10/data/train/'
    for i in range(length):
        val = (str(i+1))
    #     print(train_path + val+'.png')
        lst_train.append(ndimage.imread(path + val+'.png'))

    #Convert list to nd array    
    return(np.array(lst_train))

# %%
# convert train data to ndarray
train_path = 'F:/cifar10/data/train/'
np_train = convert_images_to_array(train_path, 50000)
# Out:
# train done

# %%
print(np_train.shape)
# Out:
# (50000, 32, 32, 3)

# %%
df_label = pd.read_csv('F:/cifar10/data/trainLabels.csv')

# %%
df_label.head()
# Out:
#    id       label
# 0   1        frog
# 1   2       truck
# 2   3       truck
# 3   4        deer
# 4   5  automobile

# %%
np_label = np.array(df_label.ix[:,0])

# %%
np_label.shape
# Out:
# (50000,)

# %%
import keras

# %%
y_nplabel = keras.utils.to_categorical(np_label, num_classes=10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-3a4e5c95cfa4> in <module>()
# ----> 1 y_nplabel = keras.utils.to_categorical(np_label, num_classes=10)
#
# C:\Users\hamza\Anaconda3\lib\site-packages\keras\utils\np_utils.py in to_categorical(y, num_classes)
#      23     n = y.shape[0]
#      24     categorical = np.zeros((n, num_classes))
# ---> 25     categorical[np.arange(n), y] = 1
#      26     return categorical
#      27
#
# IndexError: index 10 is out of bounds for axis 1 with size 10

# %% [markdown]
# # Deploy CNN

# %%
# convert test data to ndarray
test_path = 'F:/cifar10/data/test/'
np_test = convert_images_to_array(test_path, 300000)

# %%
print('train data shape', np_train.shape)
print('test data shape', np_test.shape)
# Out:
# train data shape (50000, 32, 32, 3)
# test data shape (300000, 32, 32, 3)

# %%
np_train.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### Visualize the data

# %%
from matplotlib import pyplot
from scipy.misc import toimage

# %%
pyplot.imshow(toimage(X_train[3]))
pyplot.show()
